# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
crime = pd.read_csv('Crimes_-_2020.csv', encoding = 'gbk', header = 0)

# %%
crime.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  12214699    JD423886  11/07/2020 10:30:00 AM        040XX W 24TH ST  0810
# 1  12215024    JD424116  11/07/2020 02:46:00 PM  055XX N MC VICKER AVE  0430
# 2  12215276    JD424543  11/07/2020 09:00:00 PM       001XX E 107TH ST  0620
# 3  12215844    JD425307  11/07/2020 05:00:00 AM   0000X W VAN BUREN ST  0810
# 4  12216742    JD426086  11/07/2020 12:00:00 AM      016XX S AVERS AVE  1154
#
#          Primary Type                              Description  \
# 0               THEFT                                OVER $500
# 1             BATTERY      AGGRAVATED - OTHER DANGEROUS WEAPON
# 2            BURGLARY                           UNLAWFUL ENTRY
# 3               THEFT                                OVER $500
# 4  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
#crime.isnull().sum()

# %%
crime.dropna(axis = 0, how = 'any',inplace = True)

# %%
crime.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
crime.drop(['IUCR', 'Beat', 'Ward', 'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year', 'Updated On'], axis = 1, inplace = True)

# %%
crime.shape
# Out:
# (163360, 14)

# %%
crime.rename(columns={"ID":"CrimeID"}, inplace = True)
crime.columns = crime.columns.str.upper()
crime.head()
# Out:
#       CRIMEID CASE NUMBER                    DATE                  BLOCK  \
# 167     25603    JD423602  11/07/2020 07:40:00 PM      054XX W CORTEZ ST
# 339     25598    JD423611  11/07/2020 04:07:00 AM        021XX E 72ND PL
# 409  12178135    JD381686  09/27/2020 11:00:00 PM  068XX S RIDGELAND AVE
# 508     25600    JD424303  11/07/2020 06:20:00 PM     074XX N OAKLEY AVE
# 620     25599    JD423568  11/07/2020 02:13:00 AM       059XX W HURON ST
#
#       PRIMARY TYPE                 DESCRIPTION LOCATION DESCRIPTION  ARREST  \
# 167       HOMICIDE         FIRST DEGREE MURDER               STREET    True
# 339       HOMICIDE         FIRST DEGREE MURDER                 YARD   False
# 409  OTHER OFFENSE  OTHER CRIME AGAINST PERSON            APARTMENT   False
# 508       HOMICIDE         FIRST DEGREE MURDER               STREET   False
# 620       HOMICIDE         FIRST DEGREE MURDER               STREET   False
#
#      DOMESTIC  DISTRICT  COMMUNITY AREA   LATITUDE  LONGITUDE  \
# ...

# %%
# sortedcrime = crime.sort_values(by=['Date'], ascending = False)
# sortedcrime.head(50)

# %%
crime.to_csv('Crimes2020_cleaned.csv', encoding='utf-8', index=False)
