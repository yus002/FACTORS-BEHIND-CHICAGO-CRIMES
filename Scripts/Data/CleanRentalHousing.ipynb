# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter('ignore', UserWarning)

# %%
rental = pd.read_csv('Affordable_Rental_Housing_Developments.csv', encoding = 'gbk', header = 0)
rental.columns = rental.columns.str.upper()
rental.head()
# Out:
#   COMMUNITY AREA NAME  COMMUNITY AREA NUMBER PROPERTY TYPE  \
# 0             Douglas                     35           ARO
# 1        Logan Square                     22   Multifamily
# 2     Near North Side                      8           ARO
# 3      Near West Side                     28           ARO
# 4      West Englewood                     67   Multifamily
#
#               PROPERTY NAME              ADDRESS  ZIP CODE  PHONE NUMBER  \
# 0             Lake Park LLC      243 E. 31st St.     60616  773-466-8332
# 1        Tierra Linda Apts.  1802 N. Sawyer Ave.     60647  773-276-5338
# 2         Onni Atrium Devp.      202 W. Hill St.     60610  312-585-6776
# 3                The Duncan   1515 W. Monroe St.     60607  217-779-5697
# 4  New West Englewood Homes     2109 W. 63rd St.     60636  773-434-4929
#
#          MANAGEMENT COMPANY  UNITS  X COORDINATE  Y COORDINATE  LATITUDE  \
# 0              D Properties      1           NaN           NaN       NaN
# ...

# %%
rental.drop(['X COORDINATE', 'Y COORDINATE'], axis = 1, inplace = True)
rental.head(10)
# Out:
#   COMMUNITY AREA NAME  COMMUNITY AREA NUMBER PROPERTY TYPE  \
# 0             Douglas                     35           ARO
# 1        Logan Square                     22   Multifamily
# 2     Near North Side                      8           ARO
# 3      Near West Side                     28           ARO
# 4      West Englewood                     67   Multifamily
# 5           Englewood                     68   Multifamily
# 6              Uptown                      3        Senior
# 7       Humboldt Park                     23   Multifamily
# 8     Grand Boulevard                     38   Multifamily
# 9      South Lawndale                     30   Multifamily
#
#                       PROPERTY NAME                ADDRESS  ZIP CODE  \
# 0                     Lake Park LLC        243 E. 31st St.     60616
# 1                Tierra Linda Apts.    1802 N. Sawyer Ave.     60647
# 2                 Onni Atrium Devp.        202 W. Hill St.     60610
# ...

# %%
rental.to_csv('Affordable_Rental_Housing_Developments_cleaned.csv', encoding='utf-8', index=False)
