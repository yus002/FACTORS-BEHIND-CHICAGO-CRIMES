# %%
import pandas as pd 
p = '/Users/xueruobing/Documents/Courses/Data Engenieering Platforms/Final/Cleaned Data/Poverty.csv'
e= '/Users/xueruobing/Documents/Courses/Data Engenieering Platforms/Final/Cleaned Data/Education1.csv'
i = '/Users/xueruobing/Documents/Courses/Data Engenieering Platforms/Final/Cleaned Data/Income1.csv'

poverty = pd.read_csv(p,encoding='utf-8')
education = pd.read_csv(e,encoding='utf-8')
income = pd.read_csv(i,encoding='utf-8')

# %%
poverty.head(5)
# Out:
#    Community Number  Community Name  1970 Population in Poverty  \
# 0                 1     ROGERS PARK                 4920.646393
# 1                 2      WEST RIDGE                 2894.382890
# 2                 3          UPTOWN                14219.999970
# 3                 4  LINCOLN SQUARE                 3327.000000
# 4                 5    NORTH CENTER                 3397.000000
#
#    1970 Population for whom Poverty Status is Determined  \
# 0                                        60755.23228
# 1                                        65601.02125
# 2                                        74837.99984
# 3                                        47829.00004
# 4                                        39443.00014
#
#   1970 %Poverty Population  1980 Population in Poverty  \
# 0                    8.10%                 8354.836014
# 1                    4.41%                 3465.721488
# 2                   19.00%                17613.999940
# ...

# %%
Poverty = poverty[['Community Number','2000 %Poverty Population','2010 %Poverty Population']]

# %%
Poverty.head(5)
# Out:
#    Community Number  2000 %Poverty Population  2010 %Poverty Population
# 0                 1                      0.21                      0.26
# 1                 2                      0.14                      0.17
# 2                 3                      0.25                      0.26
# 3                 4                      0.11                      0.12
# 4                 5                      0.09                      0.07

# %%
education.head(5)
# Out:
#    Community Number  Community Name  Less than High School Diploma  \
# 0                 1     ROGERS PARK                           6832
# 1                 2      WEST RIDGE                           9963
# 2                 3          UPTOWN                           5194
# 3                 4  LINCOLN SQUARE                           4017
# 4                 5    NORTH CENTER                           1134
#
#    High School Diploma, GED, or Alternative  Some College, No Degree  \
# 0                                      6738                     6884
# 1                                      9825                     8295
# 2                                      6927                     6741
# 3                                      3776                     4479
# 4                                      3087                     2844
#
#    Associates Degree  Bachelors Degree  Masters Degree  \
# 0               1972              8846            4631
# ...

# %%
Education=education[['Community Number','%Educated with no degree','%Educated with degree']]
Education.head(5)
# Out:
#    Community Number  %Educated with no degree  %Educated with degree
# 0                 1                      0.39                   0.32
# 1                 2                      0.39                   0.28
# 2                 3                      0.34                   0.46
# 3                 4                      0.32                   0.47
# 4                 5                      0.21                   0.54

# %%
income.head(5)
# Out:
#    Community Number  Community Name  Households Earning Less than $25,000  \
# 0                 1     ROGERS PARK                                  8092
# 1                 2      WEST RIDGE                                  6281
# 2                 3          UPTOWN                                 10540
# 3                 4  LINCOLN SQUARE                                  3499
# 4                 5    NORTH CENTER                                  1796
#
#    Households Earning $25,000 to $49,999  \
# 0                                   6113
# 1                                   6941
# 2                                   5392
# 3                                   3721
# 4                                   2251
#
#    Households Earning $50,000 to $74,999  \
# 0                                   4026
# 1                                   4195
# 2                                   4157
# 3                                   3747
# 4                                   2484
#
# ...

# %%
Income=income[['Community Number','%Households Earning less than $49,999','%Households Earning 50,000_99,999','%Households Earning $100,000 or more']]

# %%
Income.head(5)
# Out:
#    Community Number  %Households Earning less than $49,999  \
# 0                 1                                   0.59
# 1                 2                                   0.54
# 2                 3                                   0.54
# 3                 4                                   0.41
# 4                 5                                   0.27
#
#    %Households Earning 50,000_99,999  %Households Earning $100,000 or more
# 0                               0.25                                  0.16
# 1                               0.28                                  0.18
# 2                               0.25                                  0.21
# 3                               0.35                                  0.24
# 4                               0.29                                  0.44

# %%
Poverty.to_csv('/Users/xueruobing/Documents/Courses/Data Engenieering Platforms/Final/Cleaned Data/Povertyf.csv')
Education.to_csv('/Users/xueruobing/Documents/Courses/Data Engenieering Platforms/Final/Cleaned Data/Educationf.csv')
Income.to_csv('/Users/xueruobing/Documents/Courses/Data Engenieering Platforms/Final/Cleaned Data/Incomef.csv')
